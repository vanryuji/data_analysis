# %% [markdown]
# <a href="https://colab.research.google.com/github/vanryuji/data_analysis/blob/master/qanda_review/word_2_vector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install konlpy
# !pip list
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Requirement already satisfied: JPype1>=0.5.7 in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.6.3)
# Package                  Version
# ------------------------ ---------------------
# absl-py                  0.7.1
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   3.0.1
# astor                    0.8.0
# astropy                  3.0.5
# atari-py                 0.1.15
# atomicwrites             1.3.0
# attrs                    19.1.0
# audioread                2.1.8
# autograd                 1.2
# Babel                    2.7.0
# backcall                 0.1.0
# backports.tempfile       1.0
# backports.weakref        1.0.post1
# beautifulsoup4           4.6.3
# bleach                   3.1.0
# bokeh                    1.0.4
# boto                     2.49.0
# boto3                    1.9.162
# botocore                 1.12.162
# Bottleneck               1.2.1
# branca                   0.3.1
# bs4                      0.0.1
# bz2file                  0.98
# cachetools               3.1.1
# certifi                  2019.3.9
# cffi                     1.12.3
# chainer                  5.4.0
# chardet                  3.0.4
# Click                    7.0
# cloudpickle              0.6.1
# cmake                    3.12.0
# colorlover               0.3.0
# community                1.0.0b1
# contextlib2              0.5.5
# convertdate              2.1.3
# coverage                 3.7.1
# coveralls                0.5
# crcmod                   1.7
# cufflinks                0.14.6
# cvxopt                   1.2.3
# cvxpy                    1.0.15
# cycler                   0.10.0
# cymem                    2.0.2
# Cython                   0.29.10
# cytoolz                  0.9.0.1
# daft                     0.0.4
# dask                     1.1.5
# dataclasses              0.6
# datascience              0.10.6
# decorator                4.4.0
# defusedxml               0.6.0
# dill                     0.2.9
# distributed              1.25.3
# Django                   2.2.2
# dlib                     19.16.0
# dm-sonnet                1.33
# docopt                   0.6.2
# docutils                 0.14
# dopamine-rl              1.0.5
# easydict                 1.9
# ecos                     2.0.7.post1
# editdistance             0.5.3
# en-core-web-sm           2.0.0
# entrypoints              0.3
# enum34                   1.1.6
# ephem                    3.7.6.0
# et-xmlfile               1.0.1
# fa2                      0.3.5
# fancyimpute              0.4.3
# fastai                   1.0.52
# fastcache                1.1.0
# fastdtw                  0.3.2
# fastprogress             0.1.21
# fastrlock                0.4
# fbprophet                0.5
# feather-format           0.4.0
# featuretools             0.4.1
# filelock                 3.0.12
# fix-yahoo-finance        0.0.22
# Flask                    1.0.3
# folium                   0.8.3
# future                   0.16.0
# gast                     0.2.2
# GDAL                     2.2.2
# gdown                    3.6.4
# gensim                   3.6.0
# geographiclib            1.49
# geopy                    1.17.0
# gevent                   1.4.0
# gin-config               0.1.4
# glob2                    0.6
# google                   2.0.2
# google-api-core          1.11.1
# google-api-python-client 1.6.7
# google-auth              1.4.2
# google-auth-httplib2     0.0.3
# google-auth-oauthlib     0.3.0
# google-cloud-bigquery    1.8.1
# google-cloud-core        0.29.1
# google-cloud-language    1.0.2
# google-cloud-storage     1.13.2
# google-cloud-translate   1.3.3
# google-colab             1.0.0
# google-resumable-media   0.3.2
# googleapis-common-protos 1.6.0
# googledrivedownloader    0.4
# graph-nets               1.0.4
# graphviz                 0.10.1
# greenlet                 0.4.15
# grpcio                   1.15.0
# gspread                  3.0.1
# gspread-dataframe        3.0.2
# gunicorn                 19.9.0
# gym                      0.10.11
# h5py                     2.8.0
# HeapDict                 1.0.0
# holidays                 0.9.10
# html5lib                 1.0.1
# httpimport               0.5.16
# httplib2                 0.11.3
# humanize                 0.5.1
# hyperopt                 0.1.2
# ideep4py                 2.0.0.post3
# idna                     2.8
# image                    1.5.27
# imageio                  2.4.1
# imagesize                1.1.0
# imbalanced-learn         0.4.3
# imblearn                 0.0
# imgaug                   0.2.9
# importlib-metadata       0.17
# imutils                  0.5.2
# inflect                  2.1.0
# intel-openmp             2019.0
# intervaltree             2.1.0
# ipykernel                4.6.1
# ipython                  5.5.0
# ipython-genutils         0.2.0
# ipython-sql              0.3.9
# ipywidgets               7.4.2
# itsdangerous             1.1.0
# jdcal                    1.4.1
# jedi                     0.13.3
# jieba                    0.39
# Jinja2                   2.10.1
# jmespath                 0.9.4
# joblib                   0.13.2
# jpeg4py                  0.1.4
# JPype1                   0.6.3
# jsonschema               2.6.0
# jupyter                  1.0.0
# jupyter-client           5.2.4
# jupyter-console          6.0.0
# jupyter-core             4.4.0
# kaggle                   1.5.4
# kapre                    0.1.3.1
# Keras                    2.2.4
# Keras-Applications       1.0.8
# Keras-Preprocessing      1.1.0
# keras-vis                0.4.1
# kiwisolver               1.1.0
# knnimpute                0.1.0
# konlpy                   0.5.1
# librosa                  0.6.3
# lightgbm                 2.2.3
# llvmlite                 0.29.0
# lmdb                     0.94
# lucid                    0.3.8
# lunardate                0.2.0
# lxml                     4.2.6
# magenta                  0.3.19
# Markdown                 3.1.1
# MarkupSafe               1.1.1
# matplotlib               3.0.3
# matplotlib-venn          0.11.5
# mesh-tensorflow          0.0.5
# mido                     1.2.6
# mir-eval                 0.5
# missingno                0.4.1
# mistune                  0.8.4
# mkl                      2019.0
# mlxtend                  0.14.0
# mock                     3.0.5
# more-itertools           7.0.0
# moviepy                  0.2.3.5
# mpi4py                   3.0.1
# mpmath                   1.1.0
# msgpack                  0.5.6
# msgpack-numpy            0.4.3.2
# multiprocess             0.70.7
# multitasking             0.0.9
# murmurhash               1.0.2
# music21                  5.5.0
# natsort                  5.5.0
# nbconvert                5.5.0
# nbformat                 4.4.0
# networkx                 2.3
# nibabel                  2.3.3
# nltk                     3.2.5
# nose                     1.3.7
# notebook                 5.2.2
# np-utils                 0.5.10.0
# numba                    0.40.1
# numexpr                  2.6.9
# numpy                    1.16.4
# nvidia-ml-py3            7.352.0
# oauth2client             4.1.3
# oauthlib                 3.0.1
# okgrade                  0.4.3
# olefile                  0.46
# opencv-contrib-python    3.4.3.18
# opencv-python            3.4.5.20
# openpyxl                 2.5.9
# osqp                     0.5.0
# packaging                19.0
# pandas                   0.24.2
# pandas-datareader        0.7.0
# pandas-gbq               0.4.1
# pandas-profiling         1.4.1
# pandocfilters            1.4.2
# parso                    0.4.0
# pathlib                  1.0.1
# patsy                    0.5.1
# pexpect                  4.7.0
# pickleshare              0.7.5
# Pillow                   4.3.0
# pip                      19.1.1
# pip-tools                3.6.1
# plac                     0.9.6
# plotly                   3.6.1
# pluggy                   0.7.1
# portpicker               1.2.0
# prefetch-generator       1.0.1
# preshed                  2.0.1
# pretty-midi              0.2.8
# prettytable              0.7.2
# progressbar2             3.38.0
# prometheus-client        0.6.0
# promise                  2.2.1
# prompt-toolkit           1.0.16
# protobuf                 3.7.1
# psutil                   5.4.8
# psycopg2                 2.7.6.1
# ptyprocess               0.6.0
# py                       1.8.0
# pyarrow                  0.13.0
# pyasn1                   0.4.5
# pyasn1-modules           0.2.5
# pycocotools              2.0.0
# pycparser                2.19
# pydot                    1.3.0
# pydot-ng                 2.0.0
# pydotplus                2.0.2
# pyemd                    0.5.1
# pyglet                   1.3.2
# Pygments                 2.1.3
# pygobject                3.26.1
# pymc3                    3.7
# pymongo                  3.8.0
# pymystem3                0.2.0
# PyOpenGL                 3.1.0
# pyparsing                2.4.0
# pyrsistent               0.15.2
# pysndfile                1.3.3
# PySocks                  1.7.0
# pystan                   2.19.0.0
# pytest                   3.6.4
# python-apt               1.6.4
# python-chess             0.23.11
# python-dateutil          2.5.3
# python-louvain           0.13
# python-rtmidi            1.3.0
# python-slugify           3.0.2
# python-utils             2.3.0
# pytz                     2018.9
# PyWavelets               1.0.3
# PyYAML                   3.13
# pyzmq                    17.0.0
# qtconsole                4.5.1
# regex                    2018.1.10
# requests                 2.21.0
# requests-oauthlib        1.2.0
# resampy                  0.2.1
# retrying                 1.3.3
# rpy2                     2.9.5
# rsa                      4.0
# s3fs                     0.2.1
# s3transfer               0.2.1
# scikit-image             0.15.0
# scikit-learn             0.21.2
# scipy                    1.3.0
# screen-resolution-extra  0.0.0
# scs                      2.1.0
# seaborn                  0.9.0
# semantic-version         2.6.0
# Send2Trash               1.5.0
# setuptools               41.0.1
# setuptools-git           1.2
# Shapely                  1.6.4.post2
# simplegeneric            0.8.1
# six                      1.12.0
# sklearn                  0.0
# sklearn-pandas           1.8.0
# smart-open               1.8.4
# snowballstemmer          1.2.1
# sortedcontainers         2.1.0
# spacy                    2.0.18
# Sphinx                   1.8.5
# sphinxcontrib-websupport 1.1.2
# SQLAlchemy               1.3.4
# sqlparse                 0.3.0
# stable-baselines         2.2.1
# statsmodels              0.9.0
# sympy                    1.1.1
# tables                   3.4.4
# tabulate                 0.8.3
# tblib                    1.4.0
# tensor2tensor            1.11.0
# tensorboard              1.13.1
# tensorboardcolab         0.0.22
# tensorflow               1.13.1
# tensorflow-estimator     1.13.0
# tensorflow-hub           0.4.0
# tensorflow-metadata      0.13.0
# tensorflow-probability   0.6.0
# termcolor                1.1.0
# terminado                0.8.2
# testpath                 0.4.2
# text-unidecode           1.2
# textblob                 0.15.3
# textgenrnn               1.4.1
# tfds-nightly             1.0.2.dev201906050105
# tflearn                  0.3.2
# Theano                   1.0.4
# thinc                    6.12.1
# toolz                    0.9.0
# torch                    1.1.0
# torchsummary             1.5.1
# torchtext                0.3.1
# torchvision              0.3.0
# tornado                  4.5.3
# tqdm                     4.28.1
# traitlets                4.3.2
# tweepy                   3.6.0
# typing                   3.6.6
# tzlocal                  1.5.1
# ujson                    1.35
# umap-learn               0.3.9
# uritemplate              3.0.0
# urllib3                  1.24.3
# vega-datasets            0.7.0
# wcwidth                  0.1.7
# webencodings             0.5.1
# Werkzeug                 0.15.4
# wheel                    0.33.4
# widgetsnbextension       3.4.2
# wordcloud                1.5.0
# wrapt                    1.10.11
# xarray                   0.11.3
# xgboost                  0.90
# xkit                     0.0.0
# xlrd                     1.1.0
# xlwt                     1.3.0
# yellowbrick              0.9.1
# zict                     0.1.4
# zipp                     0.5.1
# zmq                      0.0.0

# %%
import pandas as pd
import datetime
import logging
import plotly
import numpy as np
import plotly.graph_objs as go
import plotly.plotly as py
from konlpy.tag import Okt
from collections import Counter
from gensim.models import Word2Vec
from sklearn.manifold import TSNE

# %% [markdown]
# # Download Qanda review

# %%
# !rm -rf Medium_material
# !git clone https://github.com/mathpresso/Medium_material.git
review_data = 'Medium_material/qanda_review/sample_201803.csv'
# !ls -l
# Out:
# Cloning into 'Medium_material'...
# remote: Enumerating objects: 9, done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 9
# Unpacking objects: 100% (9/9), done.
# total 12
# drwxr-xr-x 4 root root 4096 Jun 10 10:49 Medium_material
# drwxr-xr-x 3 root root 4096 Jun 10 10:46 NanumBarunGothic
# drwxr-xr-x 1 root root 4096 May 31 16:17 sample_data

# %% [markdown]
# # Load Qanda review

# %%
def change_to_datetime(submit_string):
    year = submit_string.split('-')[0]
    month = submit_string.split('-')[1]
    day = submit_string.split('-')[2].split('T')[0]
    
    return datetime.datetime(int(year), int(month), int(day))

# %%
origin = pd.read_csv(review_data)
origin['Date_Time'] = origin['Review Submit Date and Time'].apply(lambda info_str: change_to_datetime(info_str))
origin = origin[['Review Text', 'Review Title', 'Date_Time']]
origin.index = range(len(origin))
origin.head()
# Out:
#                                          Review Text  Review Title  Date_Time
# 0                                                NaN           NaN 2018-03-01
# 1                                              진짜좋군뇨           NaN 2018-03-01
# 2  모르는 문제 있으면 바로바로 앱으로 알수있어서 완전좋습니다조아요 풀이도 이해가기쉽게...           NaN 2018-03-01
# 3                                        진짜 좋은것 같아요!           NaN 2018-03-01
# 4                                             조..조아여           NaN 2018-03-01

# %% [markdown]
# # Word2Vector

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

def get_processed_data(origin_df, start_date, end_date):
    
    query = origin_df[(origin_df.Date_Time >= start_date) & (origin_df.Date_Time <= end_date)]

    q = query[['Review Text', 'Date_Time']].dropna()
    q.columns = ['Reviews', 'Date_Time']
    q.index = range(len(q))

    parser = Okt()
    q['preprocess'] = q.Reviews.apply(lambda text : " ".join(parser.morphs(text)))
    cnt = Counter(word for line in q.preprocess for word in line.split())
    
    return q, cnt

# %%
# set credentials

# To obtain api key, sign up to https://plot.ly/
# Refer : https://plot.ly/products/cloud/

# TODO : remove personal key
username = 'your_plot_id'
api_key = 'your_plot_api_key'
plotly.tools.set_credentials_file(username=username, api_key=api_key)

# %%
# query

query, counter = get_processed_data(origin, '2011-08-01', '2018-10-10')

# %%
# embedding

embedding_model = Word2Vec([line.split() for line in query.preprocess], size=100, window=5, min_count=20, workers=4, iter=50, sg=1)
# Out:
# 2019-06-10 10:49:23,722 : INFO : collecting all words and their counts
# 2019-06-10 10:49:23,729 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-06-10 10:49:23,739 : INFO : collected 5297 word types from a corpus of 38175 raw words and 3007 sentences
# 2019-06-10 10:49:23,740 : INFO : Loading a fresh vocabulary
# 2019-06-10 10:49:23,746 : INFO : effective_min_count=20 retains 281 unique words (5% of original 5297, drops 5016)
# 2019-06-10 10:49:23,747 : INFO : effective_min_count=20 leaves 26129 word corpus (68% of original 38175, drops 12046)
# 2019-06-10 10:49:23,750 : INFO : deleting the raw counts dictionary of 5297 items
# 2019-06-10 10:49:23,751 : INFO : sample=0.001 downsamples 89 most-common words
# 2019-06-10 10:49:23,752 : INFO : downsampling leaves estimated 15472 word corpus (59.2% of prior 26129)
# 2019-06-10 10:49:23,753 : INFO : estimated required memory for 281 words and 100 dimensions: 365300 bytes
# 2019-06-10 10:49:23,755 : INFO : resetting layer weights
# 2019-06-10 10:49:23,761 : INFO : training model with 4 workers on 281 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2019-06-10 10:49:23,794 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:23,808 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:23,821 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:23,824 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:23,825 : INFO : EPOCH - 1 : training on 38175 raw words (15447 effective words) took 0.1s, 299655 effective words/s
# 2019-06-10 10:49:23,863 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:23,884 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:23,902 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:23,904 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:23,905 : INFO : EPOCH - 2 : training on 38175 raw words (15485 effective words) took 0.1s, 220724 effective words/s
# 2019-06-10 10:49:23,939 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:23,958 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:23,968 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:23,972 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:23,972 : INFO : EPOCH - 3 : training on 38175 raw words (15560 effective words) took 0.1s, 278144 effective words/s
# 2019-06-10 10:49:24,007 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,026 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,037 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,040 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,041 : INFO : EPOCH - 4 : training on 38175 raw words (15511 effective words) took 0.1s, 264778 effective words/s
# 2019-06-10 10:49:24,073 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,089 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,098 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,101 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,102 : INFO : EPOCH - 5 : training on 38175 raw words (15464 effective words) took 0.1s, 293891 effective words/s
# 2019-06-10 10:49:24,132 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,148 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,152 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,160 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,161 : INFO : EPOCH - 6 : training on 38175 raw words (15450 effective words) took 0.1s, 306228 effective words/s
# 2019-06-10 10:49:24,208 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,209 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,215 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,226 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,227 : INFO : EPOCH - 7 : training on 38175 raw words (15559 effective words) took 0.1s, 273974 effective words/s
# 2019-06-10 10:49:24,257 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,277 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,283 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,287 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,289 : INFO : EPOCH - 8 : training on 38175 raw words (15472 effective words) took 0.1s, 284192 effective words/s
# 2019-06-10 10:49:24,319 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,336 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,346 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,349 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,350 : INFO : EPOCH - 9 : training on 38175 raw words (15548 effective words) took 0.1s, 295494 effective words/s
# 2019-06-10 10:49:24,408 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,409 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,411 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,414 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,415 : INFO : EPOCH - 10 : training on 38175 raw words (15444 effective words) took 0.1s, 273271 effective words/s
# 2019-06-10 10:49:24,452 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,472 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,480 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,480 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,482 : INFO : EPOCH - 11 : training on 38175 raw words (15537 effective words) took 0.1s, 297579 effective words/s
# 2019-06-10 10:49:24,529 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,533 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,539 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,543 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,544 : INFO : EPOCH - 12 : training on 38175 raw words (15330 effective words) took 0.1s, 295996 effective words/s
# 2019-06-10 10:49:24,575 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,588 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,601 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,608 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,609 : INFO : EPOCH - 13 : training on 38175 raw words (15439 effective words) took 0.1s, 276762 effective words/s
# 2019-06-10 10:49:24,642 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,662 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,669 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,673 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,675 : INFO : EPOCH - 14 : training on 38175 raw words (15592 effective words) took 0.1s, 281541 effective words/s
# 2019-06-10 10:49:24,726 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,727 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,730 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,732 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,734 : INFO : EPOCH - 15 : training on 38175 raw words (15525 effective words) took 0.1s, 303675 effective words/s
# 2019-06-10 10:49:24,771 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,784 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,798 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,803 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,804 : INFO : EPOCH - 16 : training on 38175 raw words (15411 effective words) took 0.1s, 281624 effective words/s
# 2019-06-10 10:49:24,863 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,864 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,865 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,866 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,867 : INFO : EPOCH - 17 : training on 38175 raw words (15537 effective words) took 0.1s, 297788 effective words/s
# 2019-06-10 10:49:24,918 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,925 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,928 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,929 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:24,933 : INFO : EPOCH - 18 : training on 38175 raw words (15535 effective words) took 0.1s, 300152 effective words/s
# 2019-06-10 10:49:24,967 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:24,986 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:24,997 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:24,997 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,000 : INFO : EPOCH - 19 : training on 38175 raw words (15435 effective words) took 0.1s, 285015 effective words/s
# 2019-06-10 10:49:25,032 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,047 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,057 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,064 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,065 : INFO : EPOCH - 20 : training on 38175 raw words (15372 effective words) took 0.1s, 275370 effective words/s
# 2019-06-10 10:49:25,098 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,117 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,126 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,127 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,128 : INFO : EPOCH - 21 : training on 38175 raw words (15516 effective words) took 0.1s, 298951 effective words/s
# 2019-06-10 10:49:25,161 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,182 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,187 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,192 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,193 : INFO : EPOCH - 22 : training on 38175 raw words (15484 effective words) took 0.1s, 289176 effective words/s
# 2019-06-10 10:49:25,237 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,245 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,252 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,255 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,255 : INFO : EPOCH - 23 : training on 38175 raw words (15495 effective words) took 0.1s, 290235 effective words/s
# 2019-06-10 10:49:25,311 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,312 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,319 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,321 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,322 : INFO : EPOCH - 24 : training on 38175 raw words (15528 effective words) took 0.1s, 280374 effective words/s
# 2019-06-10 10:49:25,370 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,377 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,379 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,384 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,385 : INFO : EPOCH - 25 : training on 38175 raw words (15558 effective words) took 0.1s, 284929 effective words/s
# 2019-06-10 10:49:25,413 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,433 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,438 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,446 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,447 : INFO : EPOCH - 26 : training on 38175 raw words (15482 effective words) took 0.1s, 282840 effective words/s
# 2019-06-10 10:49:25,503 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,504 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,505 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,508 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,509 : INFO : EPOCH - 27 : training on 38175 raw words (15482 effective words) took 0.1s, 307278 effective words/s
# 2019-06-10 10:49:25,543 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,560 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,569 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,570 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,571 : INFO : EPOCH - 28 : training on 38175 raw words (15589 effective words) took 0.1s, 311106 effective words/s
# 2019-06-10 10:49:25,602 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,616 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,628 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,635 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,636 : INFO : EPOCH - 29 : training on 38175 raw words (15436 effective words) took 0.1s, 283298 effective words/s
# 2019-06-10 10:49:25,666 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,687 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,691 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,698 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,699 : INFO : EPOCH - 30 : training on 38175 raw words (15450 effective words) took 0.1s, 282183 effective words/s
# 2019-06-10 10:49:25,733 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,744 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,760 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,765 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,766 : INFO : EPOCH - 31 : training on 38175 raw words (15471 effective words) took 0.1s, 270993 effective words/s
# 2019-06-10 10:49:25,813 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,819 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,820 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,827 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,828 : INFO : EPOCH - 32 : training on 38175 raw words (15393 effective words) took 0.1s, 287238 effective words/s
# 2019-06-10 10:49:25,858 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,872 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,882 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,886 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,887 : INFO : EPOCH - 33 : training on 38175 raw words (15489 effective words) took 0.0s, 318661 effective words/s
# 2019-06-10 10:49:25,916 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,936 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:25,940 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:25,945 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:25,946 : INFO : EPOCH - 34 : training on 38175 raw words (15453 effective words) took 0.1s, 305274 effective words/s
# 2019-06-10 10:49:25,978 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:25,991 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,002 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,009 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,010 : INFO : EPOCH - 35 : training on 38175 raw words (15440 effective words) took 0.1s, 284109 effective words/s
# 2019-06-10 10:49:26,047 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,058 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,067 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,070 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,070 : INFO : EPOCH - 36 : training on 38175 raw words (15403 effective words) took 0.1s, 298979 effective words/s
# 2019-06-10 10:49:26,109 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,110 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,126 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,130 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,131 : INFO : EPOCH - 37 : training on 38175 raw words (15496 effective words) took 0.1s, 302821 effective words/s
# 2019-06-10 10:49:26,174 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,175 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,183 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,188 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,189 : INFO : EPOCH - 38 : training on 38175 raw words (15419 effective words) took 0.0s, 317128 effective words/s
# 2019-06-10 10:49:26,240 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,241 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,241 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,244 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,246 : INFO : EPOCH - 39 : training on 38175 raw words (15549 effective words) took 0.0s, 317405 effective words/s
# 2019-06-10 10:49:26,281 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,299 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,307 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,315 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,316 : INFO : EPOCH - 40 : training on 38175 raw words (15424 effective words) took 0.1s, 279553 effective words/s
# 2019-06-10 10:49:26,353 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,370 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,379 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,381 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,382 : INFO : EPOCH - 41 : training on 38175 raw words (15494 effective words) took 0.1s, 271140 effective words/s
# 2019-06-10 10:49:26,429 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,435 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,442 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,447 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,447 : INFO : EPOCH - 42 : training on 38175 raw words (15567 effective words) took 0.1s, 283864 effective words/s
# 2019-06-10 10:49:26,479 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,500 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,505 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,508 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,509 : INFO : EPOCH - 43 : training on 38175 raw words (15417 effective words) took 0.1s, 297336 effective words/s
# 2019-06-10 10:49:26,559 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,561 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,567 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,568 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,569 : INFO : EPOCH - 44 : training on 38175 raw words (15456 effective words) took 0.1s, 298158 effective words/s
# 2019-06-10 10:49:26,601 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,616 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,629 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,631 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,633 : INFO : EPOCH - 45 : training on 38175 raw words (15488 effective words) took 0.1s, 270855 effective words/s
# 2019-06-10 10:49:26,688 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,689 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,690 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,693 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,695 : INFO : EPOCH - 46 : training on 38175 raw words (15553 effective words) took 0.1s, 305331 effective words/s
# 2019-06-10 10:49:26,729 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,751 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,755 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,758 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,759 : INFO : EPOCH - 47 : training on 38175 raw words (15546 effective words) took 0.1s, 298159 effective words/s
# 2019-06-10 10:49:26,808 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,811 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,819 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,820 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,821 : INFO : EPOCH - 48 : training on 38175 raw words (15573 effective words) took 0.1s, 297645 effective words/s
# 2019-06-10 10:49:26,875 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,876 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,877 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,879 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,881 : INFO : EPOCH - 49 : training on 38175 raw words (15416 effective words) took 0.0s, 313330 effective words/s
# 2019-06-10 10:49:26,929 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-10 10:49:26,933 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-10 10:49:26,940 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-10 10:49:26,947 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-10 10:49:26,948 : INFO : EPOCH - 50 : training on 38175 raw words (15474 effective words) took 0.1s, 288709 effective words/s
# 2019-06-10 10:49:26,948 : INFO : training on a 1908750 raw words (774194 effective words) took 3.2s, 242932 effective words/s

# %%
# visualization

X = np.array([embedding_model.wv.get_vector(word) for word in embedding_model.wv.vocab.keys()])
voca = list(embedding_model.wv.vocab.keys())
X_embeded = TSNE(n_components=2).fit_transform(X)

trace2 = go.Scatter(
    x=[x for x, y in X_embeded],
    y=[y for x, y in X_embeded],
    mode='markers+text',
    name='Markers and Text',
    text=voca,
    textposition='bottom center'
)

data = [trace2]
layout = go.Layout(
    showlegend=False
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='text-chart-basic')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~vanryuji/0 or inside your plot.ly account where it is named 'text-chart-basic'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~vanryuji/0.embed" height="525px" width="100%"></iframe>
